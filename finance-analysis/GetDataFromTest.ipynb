# %%
import pandas as pd

# %%
df = pd.read_csv("fraudTest.csv")
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
# 随机抽取 10 行数据
random_sample = df.sample(n=10, random_state=43)  # random_state 确保结果可复现
random_sample
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 121907      121907   2020-08-03 01:57:13      180064817343047
# 60895        60895   2020-07-12 16:38:29     2720830304681674
# 97845        97845   2020-07-25 18:26:32     2252055259910912
# 431229      431229   2020-12-04 18:04:18     2348245054386329
# 14371        14371   2020-06-26 05:47:02  4208110975550360171
# 283137      283137   2020-10-05 06:17:25     4518350514020532
# 307120      307120   2020-10-15 15:35:55     3589255887819806
# 232003      232003   2020-09-13 03:15:41      370612217861404
# 4438          4438   2020-06-22 15:58:12      180067784565096
# 457185      457185   2020-12-10 00:17:55     5456776410929288
#
#                                     merchant      category     amt  \
# 121907                      fraud_Mohr-Bayer  shopping_net    1.66
# 60895   fraud_Moore, Williamson and Emmerich          home   69.17
# 97845    fraud_Schumm, McLaughlin and Carter   food_dining   58.14
# ...

# %%
random_sample.to_csv("../finance-server/uploads/RandomTest3.csv")
