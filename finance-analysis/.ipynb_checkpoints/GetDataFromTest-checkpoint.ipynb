# %%
import pandas as pd

# %%
df = pd.read_csv("fraudTest.csv")
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
# 随机抽取 10 行数据
random_sample = df.sample(n=10, random_state=42)  # random_state 确保结果可复现
random_sample
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 119106      119106   2020-08-02 07:55:28   377895991033232
# 179292      179292   2020-08-23 14:05:16    30364087349027
# 540729      540729   2020-12-28 16:22:29    30328384440870
# 374360      374360   2020-11-14 10:44:50    30364087349027
# 314574      314574   2020-10-19 01:50:09     4198470814557
# 377296      377296   2020-11-15 17:04:04   213126662687660
# 399943      399943   2020-11-24 22:26:16      639023984367
# 1481          1481   2020-06-21 20:46:20     4990494243023
# 465665      465665   2020-12-12 10:15:23  4452366298769043
# 430957      430957   2020-12-04 16:31:41   180094419304907
#
#                                     merchant        category    amt  \
# 119106   fraud_Bahringer, Schoen and Corkery    shopping_pos   1.07
# 179292     fraud_Romaguera, Wehner and Tromp       kids_pets  94.99
# 540729                     fraud_Berge-Hills       kids_pets  31.28
# ...

# %%
random_sample.to_csv("../finance-server/uploads/RandomTest.csv")
