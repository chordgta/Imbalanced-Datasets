# %%
import numpy as np

class Environment:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.grid = [[0 for _ in range(width)] for _ in range(height)]  # 0 表示可飞行，1 表示障碍物

    def set_obstacle(self, x, y):
        self.grid[y][x] = 1

class ACO:
    def __init__(self, environment, num_ants, evaporation_rate, Q, alpha, beta, max_iterations):
        self.environment = environment
        self.num_ants = num_ants
        self.evaporation_rate = evaporation_rate
        self.Q = Q
        self.alpha = alpha
        self.beta = beta
        self.max_iterations = max_iterations
        self.pheromone = [[1.0 for _ in range(environment.width)] for _ in range(environment.height)]

    def find_path(self, start, goal):
        best_path = None
        for iteration in range(self.max_iterations):
            paths = []
            for _ in range(self.num_ants):
                path = self.construct_path(start, goal)
                paths.append(path)
                if best_path is None or len(path) < len(best_path):
                    best_path = path
            self.update_pheromone(paths)
        return best_path

    def construct_path(self, start, goal):
        path = []
        current_node = start
        visited = set()
        visited.add(current_node)
        while current_node != goal:
            neighbors = get_neighbors(current_node, self.environment)
            allowed_nodes = [node for node in neighbors if node not in visited and self.environment.grid[node[1]][node[0]] == 0]
            if not allowed_nodes:
                break  # 无路可走
            next_node = self.select_next_node(current_node, allowed_nodes)
            path.append(next_node)
            visited.add(next_node)
            current_node = next_node
        return path

    def select_next_node(self, current_node, allowed_nodes):
        probabilities = []
        total = 0
        for node in allowed_nodes:
            pheromone = self.pheromone[node[1]][node[0]]
            distance = 1 / manhattan_distance(current_node, node)
            probability = (pheromone ** self.alpha) * (distance ** self.beta)
            probabilities.append(probability)
            total += probability
        if total == 0:
            return allowed_nodes[np.random.choice(len(allowed_nodes))]
        probabilities = [p / total for p in probabilities]
        print(f"Current node: {current_node}, allowed nodes: {allowed_nodes}, probabilities: {probabilities}")  # Debug info
        return allowed_nodes[np.random.choice(len(allowed_nodes), p=probabilities)]


    def update_pheromone(self, paths):
        # 信息素挥发
        for y in range(self.environment.height):
            for x in range(self.environment.width):
                self.pheromone[y][x] *= (1 - self.evaporation_rate)

        # 信息素增强
        for path in paths:
            path_length = len(path)
            if path_length == 0:
                continue
            delta_pheromone = self.Q / path_length
            for (x, y) in path:
                self.pheromone[y][x] += delta_pheromone

def get_neighbors(position, environment):
    x, y = position
    neighbors = []
    for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:  # 上下左右
        nx, ny = x + dx, y + dy
        if 0 <= nx < environment.width and 0 <= ny < environment.height:
            neighbors.append((nx, ny))
    return neighbors

def manhattan_distance(a, b):
    return abs(a[0] - b[0]) + abs(a[1] - b[1])

# 示例用法
env = Environment(10, 10)
env.set_obstacle(5, 5)
aco = ACO(env, num_ants=10, evaporation_rate=0.7, Q=1.0, alpha=1.0, beta=3.0, max_iterations=100)
path = aco.find_path((0, 0), (9, 9))
print("最优路径:", path)
# Out:
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 1), allowed nodes: [(0, 1), (2, 1), (1, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (0, 1), allowed nodes: [(0, 2)], probabilities: [1.0]
# Current node: (0, 2), allowed nodes: [(1, 2), (0, 3)], probabilities: [0.5, 0.5]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 4)], probabilities: [0.5, 0.5]
# Current node: (0, 4), allowed nodes: [(1, 4), (0, 5)], probabilities: [0.5, 0.5]
# Current node: (0, 5), allowed nodes: [(1, 5), (0, 6)], probabilities: [0.5, 0.5]
# Current node: (1, 5), allowed nodes: [(2, 5), (1, 4), (1, 6)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 4), allowed nodes: [(2, 4), (1, 3)], probabilities: [0.5, 0.5]
# Current node: (1, 3), allowed nodes: [(2, 3), (1, 2)], probabilities: [0.5, 0.5]
# Current node: (1, 2), allowed nodes: [(2, 2)], probabilities: [1.0]
# Current node: (2, 2), allowed nodes: [(3, 2), (2, 1), (2, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 4)], probabilities: [0.5, 0.5]
# Current node: (2, 4), allowed nodes: [(3, 4), (2, 5)], probabilities: [0.5, 0.5]
# Current node: (3, 4), allowed nodes: [(4, 4), (3, 3), (3, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 4), allowed nodes: [(5, 4), (4, 3), (4, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 3), allowed nodes: [(3, 3), (5, 3), (4, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 3), allowed nodes: [(3, 2)], probabilities: [1.0]
# Current node: (3, 2), allowed nodes: [(4, 2), (3, 1)], probabilities: [0.5, 0.5]
# Current node: (4, 2), allowed nodes: [(5, 2), (4, 1)], probabilities: [0.5, 0.5]
# Current node: (5, 2), allowed nodes: [(6, 2), (5, 1), (5, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (5, 3), allowed nodes: [(6, 3), (5, 4)], probabilities: [0.5, 0.5]
# Current node: (6, 3), allowed nodes: [(7, 3), (6, 2), (6, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (6, 2), allowed nodes: [(7, 2), (6, 1)], probabilities: [0.5, 0.5]
# Current node: (7, 2), allowed nodes: [(8, 2), (7, 1), (7, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 2), allowed nodes: [(9, 2), (8, 1), (8, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (9, 2), allowed nodes: [(9, 1), (9, 3)], probabilities: [0.5, 0.5]
# Current node: (9, 1), allowed nodes: [(8, 1), (9, 0)], probabilities: [0.5, 0.5]
# Current node: (8, 1), allowed nodes: [(7, 1), (8, 0)], probabilities: [0.5, 0.5]
# Current node: (7, 1), allowed nodes: [(6, 1), (7, 0)], probabilities: [0.5, 0.5]
# Current node: (6, 1), allowed nodes: [(5, 1), (6, 0)], probabilities: [0.5, 0.5]
# Current node: (6, 0), allowed nodes: [(5, 0), (7, 0)], probabilities: [0.5, 0.5]
# Current node: (5, 0), allowed nodes: [(4, 0), (5, 1)], probabilities: [0.5, 0.5]
# Current node: (5, 1), allowed nodes: [(4, 1)], probabilities: [1.0]
# Current node: (4, 1), allowed nodes: [(3, 1), (4, 0)], probabilities: [0.5, 0.5]
# Current node: (4, 0), allowed nodes: [(3, 0)], probabilities: [1.0]
# Current node: (3, 0), allowed nodes: [(2, 0), (3, 1)], probabilities: [0.5, 0.5]
# Current node: (3, 1), allowed nodes: [(2, 1)], probabilities: [1.0]
# Current node: (2, 1), allowed nodes: [(2, 0)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.5, 0.5]
# Current node: (2, 0), allowed nodes: [(3, 0), (2, 1)], probabilities: [0.5, 0.5]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.5, 0.5]
# Current node: (3, 1), allowed nodes: [(2, 1), (4, 1), (3, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 2), allowed nodes: [(2, 2), (4, 2), (3, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 2), allowed nodes: [(1, 2), (2, 1), (2, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 1), allowed nodes: [(1, 1)], probabilities: [1.0]
# Current node: (1, 1), allowed nodes: [(0, 1), (1, 2)], probabilities: [0.5, 0.5]
# Current node: (0, 1), allowed nodes: [(0, 2)], probabilities: [1.0]
# Current node: (0, 2), allowed nodes: [(1, 2), (0, 3)], probabilities: [0.5, 0.5]
# Current node: (1, 2), allowed nodes: [(1, 3)], probabilities: [1.0]
# Current node: (1, 3), allowed nodes: [(0, 3), (2, 3), (1, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 4), allowed nodes: [(0, 4), (2, 4), (1, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (0, 4), allowed nodes: [(0, 3), (0, 5)], probabilities: [0.5, 0.5]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (0, 1), allowed nodes: [(1, 1), (0, 2)], probabilities: [0.5, 0.5]
# Current node: (0, 2), allowed nodes: [(1, 2), (0, 3)], probabilities: [0.5, 0.5]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 4)], probabilities: [0.5, 0.5]
# Current node: (1, 3), allowed nodes: [(2, 3), (1, 2), (1, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 2), (2, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 3), allowed nodes: [(4, 3), (3, 2), (3, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 2), allowed nodes: [(2, 2), (4, 2), (3, 1)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 2), allowed nodes: [(5, 2), (4, 1), (4, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 1), allowed nodes: [(3, 1), (5, 1), (4, 0)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (5, 1), allowed nodes: [(6, 1), (5, 0), (5, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (5, 2), allowed nodes: [(6, 2), (5, 3)], probabilities: [0.5, 0.5]
# Current node: (6, 2), allowed nodes: [(7, 2), (6, 1), (6, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 2), allowed nodes: [(8, 2), (7, 1), (7, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 3), allowed nodes: [(6, 3), (8, 3), (7, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 3), allowed nodes: [(9, 3), (8, 2), (8, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 4), allowed nodes: [(7, 4), (9, 4), (8, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (9, 4), allowed nodes: [(9, 3), (9, 5)], probabilities: [0.5, 0.5]
# Current node: (9, 3), allowed nodes: [(9, 2)], probabilities: [1.0]
# Current node: (9, 2), allowed nodes: [(8, 2), (9, 1)], probabilities: [0.5, 0.5]
# Current node: (8, 2), allowed nodes: [(8, 1)], probabilities: [1.0]
# Current node: (8, 1), allowed nodes: [(7, 1), (9, 1), (8, 0)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (9, 1), allowed nodes: [(9, 0)], probabilities: [1.0]
# Current node: (9, 0), allowed nodes: [(8, 0)], probabilities: [1.0]
# Current node: (8, 0), allowed nodes: [(7, 0)], probabilities: [1.0]
# Current node: (7, 0), allowed nodes: [(6, 0), (7, 1)], probabilities: [0.5, 0.5]
# Current node: (7, 1), allowed nodes: [(6, 1)], probabilities: [1.0]
# Current node: (6, 1), allowed nodes: [(6, 0)], probabilities: [1.0]
# Current node: (6, 0), allowed nodes: [(5, 0)], probabilities: [1.0]
# Current node: (5, 0), allowed nodes: [(4, 0)], probabilities: [1.0]
# Current node: (4, 0), allowed nodes: [(3, 0)], probabilities: [1.0]
# Current node: (3, 0), allowed nodes: [(2, 0), (3, 1)], probabilities: [0.5, 0.5]
# Current node: (2, 0), allowed nodes: [(1, 0), (2, 1)], probabilities: [0.5, 0.5]
# Current node: (2, 1), allowed nodes: [(1, 1), (3, 1), (2, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.5, 0.5]
# Current node: (2, 0), allowed nodes: [(3, 0), (2, 1)], probabilities: [0.5, 0.5]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.5, 0.5]
# Current node: (3, 1), allowed nodes: [(2, 1), (4, 1), (3, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 1), allowed nodes: [(1, 1), (2, 2)], probabilities: [0.5, 0.5]
# Current node: (1, 1), allowed nodes: [(0, 1), (1, 2)], probabilities: [0.5, 0.5]
# Current node: (0, 1), allowed nodes: [(0, 2)], probabilities: [1.0]
# Current node: (0, 2), allowed nodes: [(1, 2), (0, 3)], probabilities: [0.5, 0.5]
# Current node: (1, 2), allowed nodes: [(2, 2), (1, 3)], probabilities: [0.5, 0.5]
# Current node: (1, 3), allowed nodes: [(0, 3), (2, 3), (1, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 2), (2, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 3), allowed nodes: [(4, 3), (3, 2), (3, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 4), allowed nodes: [(2, 4), (4, 4), (3, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 4), allowed nodes: [(1, 4), (2, 5)], probabilities: [0.5, 0.5]
# Current node: (1, 4), allowed nodes: [(0, 4), (1, 5)], probabilities: [0.5, 0.5]
# Current node: (0, 4), allowed nodes: [(0, 3), (0, 5)], probabilities: [0.5, 0.5]
# Current node: (0, 5), allowed nodes: [(1, 5), (0, 6)], probabilities: [0.5, 0.5]
# Current node: (0, 6), allowed nodes: [(1, 6), (0, 7)], probabilities: [0.5, 0.5]
# Current node: (0, 7), allowed nodes: [(1, 7), (0, 8)], probabilities: [0.5, 0.5]
# Current node: (1, 7), allowed nodes: [(2, 7), (1, 6), (1, 8)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 7), allowed nodes: [(3, 7), (2, 6), (2, 8)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 7), allowed nodes: [(4, 7), (3, 6), (3, 8)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 6), allowed nodes: [(2, 6), (4, 6), (3, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 5), allowed nodes: [(2, 5), (4, 5)], probabilities: [0.5, 0.5]
# Current node: (2, 5), allowed nodes: [(1, 5), (2, 6)], probabilities: [0.5, 0.5]
# Current node: (1, 5), allowed nodes: [(1, 6)], probabilities: [1.0]
# Current node: (1, 6), allowed nodes: [(2, 6)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (0, 1), allowed nodes: [(1, 1), (0, 2)], probabilities: [0.5, 0.5]
# Current node: (1, 1), allowed nodes: [(2, 1), (1, 0), (1, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 2), allowed nodes: [(0, 2), (2, 2), (1, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 3), allowed nodes: [(0, 3), (2, 3), (1, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 2), (2, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 3), allowed nodes: [(4, 3), (3, 2), (3, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 3), allowed nodes: [(5, 3), (4, 2), (4, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 4), allowed nodes: [(3, 4), (5, 4), (4, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 4), allowed nodes: [(2, 4), (3, 5)], probabilities: [0.5, 0.5]
# Current node: (3, 5), allowed nodes: [(2, 5), (4, 5), (3, 6)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 5), allowed nodes: [(4, 6)], probabilities: [1.0]
# Current node: (4, 6), allowed nodes: [(3, 6), (5, 6), (4, 7)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 7), allowed nodes: [(3, 7), (5, 7), (4, 8)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 8), allowed nodes: [(3, 8), (5, 8), (4, 9)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (5, 8), allowed nodes: [(6, 8), (5, 7), (5, 9)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (5, 9), allowed nodes: [(4, 9), (6, 9)], probabilities: [0.5, 0.5]
# Current node: (6, 9), allowed nodes: [(7, 9), (6, 8)], probabilities: [0.5, 0.5]
# Current node: (6, 8), allowed nodes: [(7, 8), (6, 7)], probabilities: [0.5, 0.5]
# Current node: (7, 8), allowed nodes: [(8, 8), (7, 7), (7, 9)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 9), allowed nodes: [(8, 9)], probabilities: [1.0]
# Current node: (8, 9), allowed nodes: [(9, 9), (8, 8)], probabilities: [0.5, 0.5]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 1), allowed nodes: [(0, 1), (2, 1), (1, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 2), allowed nodes: [(0, 2), (2, 2), (1, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 2), allowed nodes: [(3, 2), (2, 1), (2, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 1), allowed nodes: [(3, 1), (2, 0)], probabilities: [0.5, 0.5]
# Current node: (2, 0), allowed nodes: [(3, 0)], probabilities: [1.0]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.5, 0.5]
# Current node: (4, 0), allowed nodes: [(5, 0), (4, 1)], probabilities: [0.5, 0.5]
# Current node: (5, 0), allowed nodes: [(6, 0), (5, 1)], probabilities: [0.5, 0.5]
# Current node: (6, 0), allowed nodes: [(7, 0), (6, 1)], probabilities: [0.5, 0.5]
# Current node: (7, 0), allowed nodes: [(8, 0), (7, 1)], probabilities: [0.5, 0.5]
# Current node: (7, 1), allowed nodes: [(6, 1), (8, 1), (7, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 2), allowed nodes: [(6, 2), (8, 2), (7, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 3), allowed nodes: [(6, 3), (8, 3), (7, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 4), allowed nodes: [(6, 4), (8, 4), (7, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 4), allowed nodes: [(9, 4), (8, 3), (8, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (9, 4), allowed nodes: [(9, 3), (9, 5)], probabilities: [0.5, 0.5]
# Current node: (9, 5), allowed nodes: [(8, 5), (9, 6)], probabilities: [0.5, 0.5]
# Current node: (9, 6), allowed nodes: [(8, 6), (9, 7)], probabilities: [0.5, 0.5]
# Current node: (8, 6), allowed nodes: [(7, 6), (8, 5), (8, 7)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 7), allowed nodes: [(7, 7), (9, 7), (8, 8)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 8), allowed nodes: [(7, 8), (9, 8), (8, 9)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 8), allowed nodes: [(6, 8), (7, 7), (7, 9)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 7), allowed nodes: [(6, 7), (7, 6)], probabilities: [0.5, 0.5]
# Current node: (6, 7), allowed nodes: [(5, 7), (6, 6), (6, 8)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (5, 7), allowed nodes: [(4, 7), (5, 6), (5, 8)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (5, 8), allowed nodes: [(4, 8), (6, 8), (5, 9)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (5, 9), allowed nodes: [(4, 9), (6, 9)], probabilities: [0.5, 0.5]
# Current node: (6, 9), allowed nodes: [(7, 9), (6, 8)], probabilities: [0.5, 0.5]
# Current node: (7, 9), allowed nodes: [(8, 9)], probabilities: [1.0]
# Current node: (8, 9), allowed nodes: [(9, 9)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 1), allowed nodes: [(0, 1), (2, 1), (1, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (0, 1), allowed nodes: [(0, 2)], probabilities: [1.0]
# Current node: (0, 2), allowed nodes: [(1, 2), (0, 3)], probabilities: [0.5, 0.5]
# Current node: (1, 2), allowed nodes: [(2, 2), (1, 3)], probabilities: [0.5, 0.5]
# Current node: (1, 3), allowed nodes: [(0, 3), (2, 3), (1, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 2), (2, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 3), allowed nodes: [(4, 3), (3, 2), (3, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 2), allowed nodes: [(2, 2), (4, 2), (3, 1)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 2), allowed nodes: [(2, 1)], probabilities: [1.0]
# Current node: (2, 1), allowed nodes: [(3, 1), (2, 0)], probabilities: [0.5, 0.5]
# Current node: (3, 1), allowed nodes: [(4, 1), (3, 0)], probabilities: [0.5, 0.5]
# Current node: (3, 0), allowed nodes: [(2, 0), (4, 0)], probabilities: [0.5, 0.5]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (0, 1), allowed nodes: [(1, 1), (0, 2)], probabilities: [0.5, 0.5]
# Current node: (1, 1), allowed nodes: [(2, 1), (1, 0), (1, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 0), allowed nodes: [(2, 0)], probabilities: [1.0]
# Current node: (2, 0), allowed nodes: [(3, 0), (2, 1)], probabilities: [0.5, 0.5]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.5, 0.5]
# Current node: (4, 0), allowed nodes: [(5, 0), (4, 1)], probabilities: [0.5, 0.5]
# Current node: (5, 0), allowed nodes: [(6, 0), (5, 1)], probabilities: [0.5, 0.5]
# Current node: (6, 0), allowed nodes: [(7, 0), (6, 1)], probabilities: [0.5, 0.5]
# Current node: (6, 1), allowed nodes: [(5, 1), (7, 1), (6, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 1), allowed nodes: [(8, 1), (7, 0), (7, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 2), allowed nodes: [(6, 2), (8, 2), (7, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 3), allowed nodes: [(6, 3), (8, 3), (7, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (6, 3), allowed nodes: [(5, 3), (6, 2), (6, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (6, 4), allowed nodes: [(5, 4), (7, 4), (6, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (6, 5), allowed nodes: [(7, 5), (6, 6)], probabilities: [0.5, 0.5]
# Current node: (7, 5), allowed nodes: [(8, 5), (7, 4), (7, 6)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 6), allowed nodes: [(6, 6), (8, 6), (7, 7)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 6), allowed nodes: [(9, 6), (8, 5), (8, 7)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 7), allowed nodes: [(7, 7), (9, 7), (8, 8)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (9, 7), allowed nodes: [(9, 6), (9, 8)], probabilities: [0.5, 0.5]
# Current node: (9, 8), allowed nodes: [(8, 8), (9, 9)], probabilities: [0.5, 0.5]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (0, 1), allowed nodes: [(1, 1), (0, 2)], probabilities: [0.5, 0.5]
# Current node: (1, 1), allowed nodes: [(2, 1), (1, 0), (1, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 2), allowed nodes: [(0, 2), (2, 2), (1, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (0, 2), allowed nodes: [(0, 3)], probabilities: [1.0]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 4)], probabilities: [0.5, 0.5]
# Current node: (0, 4), allowed nodes: [(1, 4), (0, 5)], probabilities: [0.5, 0.5]
# Current node: (0, 5), allowed nodes: [(1, 5), (0, 6)], probabilities: [0.5, 0.5]
# Current node: (0, 6), allowed nodes: [(1, 6), (0, 7)], probabilities: [0.5, 0.5]
# Current node: (1, 6), allowed nodes: [(2, 6), (1, 5), (1, 7)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 7), allowed nodes: [(0, 7), (2, 7), (1, 8)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (0, 7), allowed nodes: [(0, 8)], probabilities: [1.0]
# Current node: (0, 8), allowed nodes: [(1, 8), (0, 9)], probabilities: [0.5, 0.5]
# Current node: (1, 8), allowed nodes: [(2, 8), (1, 9)], probabilities: [0.5, 0.5]
# Current node: (1, 9), allowed nodes: [(0, 9), (2, 9)], probabilities: [0.5, 0.5]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.5, 0.5]
# Current node: (1, 1), allowed nodes: [(0, 1), (2, 1), (1, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 2), allowed nodes: [(0, 2), (2, 2), (1, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (0, 2), allowed nodes: [(0, 1), (0, 3)], probabilities: [0.5, 0.5]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 4)], probabilities: [0.5, 0.5]
# Current node: (1, 3), allowed nodes: [(2, 3), (1, 4)], probabilities: [0.5, 0.5]
# Current node: (1, 4), allowed nodes: [(0, 4), (2, 4), (1, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (0, 4), allowed nodes: [(0, 5)], probabilities: [1.0]
# Current node: (0, 5), allowed nodes: [(1, 5), (0, 6)], probabilities: [0.5, 0.5]
# Current node: (0, 6), allowed nodes: [(1, 6), (0, 7)], probabilities: [0.5, 0.5]
# Current node: (1, 6), allowed nodes: [(2, 6), (1, 5), (1, 7)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (1, 5), allowed nodes: [(2, 5)], probabilities: [1.0]
# Current node: (2, 5), allowed nodes: [(3, 5), (2, 4), (2, 6)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 5), allowed nodes: [(4, 5), (3, 4), (3, 6)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (3, 4), allowed nodes: [(2, 4), (4, 4), (3, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 4), allowed nodes: [(2, 3)], probabilities: [1.0]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 2)], probabilities: [0.5, 0.5]
# Current node: (3, 3), allowed nodes: [(4, 3), (3, 2)], probabilities: [0.5, 0.5]
# Current node: (3, 2), allowed nodes: [(2, 2), (4, 2), (3, 1)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (2, 2), allowed nodes: [(2, 1)], probabilities: [1.0]
# Current node: (2, 1), allowed nodes: [(3, 1), (2, 0)], probabilities: [0.5, 0.5]
# Current node: (3, 1), allowed nodes: [(4, 1), (3, 0)], probabilities: [0.5, 0.5]
# Current node: (4, 1), allowed nodes: [(5, 1), (4, 0), (4, 2)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (4, 2), allowed nodes: [(5, 2), (4, 3)], probabilities: [0.5, 0.5]
# Current node: (5, 2), allowed nodes: [(6, 2), (5, 1), (5, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (6, 2), allowed nodes: [(7, 2), (6, 1), (6, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 2), allowed nodes: [(8, 2), (7, 1), (7, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 2), allowed nodes: [(9, 2), (8, 1), (8, 3)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 3), allowed nodes: [(7, 3), (9, 3), (8, 4)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (7, 3), allowed nodes: [(6, 3), (7, 4)], probabilities: [0.5, 0.5]
# Current node: (7, 4), allowed nodes: [(6, 4), (8, 4), (7, 5)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (8, 4), allowed nodes: [(9, 4), (8, 5)], probabilities: [0.5, 0.5]
# Current node: (9, 4), allowed nodes: [(9, 3), (9, 5)], probabilities: [0.5, 0.5]
# Current node: (9, 5), allowed nodes: [(8, 5), (9, 6)], probabilities: [0.5, 0.5]
# Current node: (8, 5), allowed nodes: [(7, 5), (8, 6)], probabilities: [0.5, 0.5]
# Current node: (8, 6), allowed nodes: [(7, 6), (9, 6), (8, 7)], probabilities: [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Current node: (9, 6), allowed nodes: [(9, 7)], probabilities: [1.0]
# Current node: (9, 7), allowed nodes: [(8, 7), (9, 8)], probabilities: [0.5, 0.5]
# Current node: (9, 8), allowed nodes: [(8, 8), (9, 9)], probabilities: [0.5, 0.5]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.46684978625736967, 0.5331502137426304]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.4591254454309356, 0.5408745545690644]
# Current node: (1, 1), allowed nodes: [(0, 1), (2, 1), (1, 2)], probabilities: [0.3539690702171459, 0.30167053028821905, 0.34436039949463504]
# Current node: (1, 2), allowed nodes: [(0, 2), (2, 2), (1, 3)], probabilities: [0.35668607819129405, 0.2988333853802739, 0.34448053642843207]
# Current node: (1, 3), allowed nodes: [(0, 3), (2, 3), (1, 4)], probabilities: [0.34248416039460816, 0.3553514478887614, 0.3021643917166305]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 2), (2, 4)], probabilities: [0.37020441026470235, 0.3613920763196628, 0.268403513415635]
# Current node: (3, 3), allowed nodes: [(4, 3), (3, 2), (3, 4)], probabilities: [0.28083239627622353, 0.39230921436810173, 0.32685838935567474]
# Current node: (4, 3), allowed nodes: [(5, 3), (4, 2), (4, 4)], probabilities: [0.30236318407960194, 0.3529850746268657, 0.3446517412935323]
# Current node: (5, 3), allowed nodes: [(6, 3), (5, 2), (5, 4)], probabilities: [0.3528587800840443, 0.3613905513816376, 0.2857506685343181]
# Current node: (5, 4), allowed nodes: [(4, 4), (6, 4)], probabilities: [0.5174603174603175, 0.48253968253968255]
# Current node: (4, 4), allowed nodes: [(3, 4), (4, 5)], probabilities: [0.5551839464882943, 0.44481605351170567]
# Current node: (4, 5), allowed nodes: [(3, 5), (4, 6)], probabilities: [0.5403887688984881, 0.45961123110151186]
# Current node: (3, 5), allowed nodes: [(2, 5), (3, 4), (3, 6)], probabilities: [0.3198963432191189, 0.38237834725021597, 0.2977253095306651]
# Current node: (3, 4), allowed nodes: [(2, 4)], probabilities: [1.0]
# Current node: (2, 4), allowed nodes: [(1, 4), (2, 5)], probabilities: [0.5563689604685212, 0.44363103953147875]
# Current node: (1, 4), allowed nodes: [(0, 4), (1, 5)], probabilities: [0.5736842105263158, 0.42631578947368426]
# Current node: (0, 4), allowed nodes: [(0, 3), (0, 5)], probabilities: [0.5312726745029749, 0.4687273254970251]
# Current node: (0, 3), allowed nodes: [(0, 2)], probabilities: [1.0]
# Current node: (0, 2), allowed nodes: [(0, 1)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.46684978625736967, 0.5331502137426304]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.4591254454309356, 0.5408745545690644]
# Current node: (2, 0), allowed nodes: [(3, 0), (2, 1)], probabilities: [0.5085987031025447, 0.49140129689745515]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.43797606709362813, 0.5620239329063719]
# Current node: (4, 0), allowed nodes: [(5, 0), (4, 1)], probabilities: [0.5318955919343532, 0.46810440806564674]
# Current node: (4, 1), allowed nodes: [(3, 1), (5, 1), (4, 2)], probabilities: [0.4298384025246204, 0.27536862723760813, 0.29479297023777135]
# Current node: (3, 1), allowed nodes: [(2, 1), (3, 2)], probabilities: [0.5303836682818333, 0.46961633171816664]
# Current node: (3, 2), allowed nodes: [(2, 2), (4, 2), (3, 3)], probabilities: [0.36298400741285386, 0.2651808329226823, 0.3718351596644638]
# Current node: (2, 2), allowed nodes: [(1, 2), (2, 1), (2, 3)], probabilities: [0.3740512710692329, 0.3276806667202042, 0.298268062210563]
# Current node: (1, 2), allowed nodes: [(0, 2), (1, 1), (1, 3)], probabilities: [0.32098604677228076, 0.36901181874896466, 0.3100021344787545]
# Current node: (0, 2), allowed nodes: [(0, 1), (0, 3)], probabilities: [0.5721926837948232, 0.42780731620517676]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 4)], probabilities: [0.5356207140090674, 0.4643792859909325]
# Current node: (0, 4), allowed nodes: [(1, 4), (0, 5)], probabilities: [0.5, 0.5]
# Current node: (1, 4), allowed nodes: [(2, 4), (1, 3), (1, 5)], probabilities: [0.281521819939038, 0.43695636012192396, 0.281521819939038]
# Current node: (1, 3), allowed nodes: [(2, 3)], probabilities: [1.0]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 4)], probabilities: [0.5797053192374927, 0.42029468076250726]
# Current node: (2, 4), allowed nodes: [(3, 4), (2, 5)], probabilities: [0.5444854448544485, 0.4555145551455514]
# Current node: (2, 5), allowed nodes: [(1, 5), (3, 5), (2, 6)], probabilities: [0.3420673769075727, 0.36020731356176217, 0.2977253095306651]
# Current node: (2, 6), allowed nodes: [(1, 6), (3, 6), (2, 7)], probabilities: [0.38894907908992415, 0.3055254604550379, 0.3055254604550379]
# Current node: (1, 6), allowed nodes: [(0, 6), (1, 5), (1, 7)], probabilities: [0.3516160626836435, 0.31733594515181196, 0.33104799216454456]
# Current node: (1, 5), allowed nodes: [(0, 5)], probabilities: [1.0]
# Current node: (0, 5), allowed nodes: [(0, 6)], probabilities: [1.0]
# Current node: (0, 6), allowed nodes: [(0, 7)], probabilities: [1.0]
# Current node: (0, 7), allowed nodes: [(1, 7), (0, 8)], probabilities: [0.523219814241486, 0.47678018575851394]
# Current node: (0, 8), allowed nodes: [(1, 8), (0, 9)], probabilities: [0.5, 0.5]
# Current node: (0, 9), allowed nodes: [(1, 9)], probabilities: [1.0]
# Current node: (1, 9), allowed nodes: [(2, 9), (1, 8)], probabilities: [0.45, 0.5499999999999999]
# Current node: (1, 8), allowed nodes: [(2, 8), (1, 7)], probabilities: [0.42711864406779665, 0.5728813559322034]
# Current node: (2, 8), allowed nodes: [(3, 8), (2, 7), (2, 9)], probabilities: [0.3206106870229008, 0.35877862595419846, 0.3206106870229008]
# Current node: (2, 7), allowed nodes: [(1, 7), (3, 7)], probabilities: [0.5451612903225806, 0.45483870967741935]
# Current node: (3, 7), allowed nodes: [(4, 7), (3, 6), (3, 8)], probabilities: [0.35208471211118464, 0.3421575115817339, 0.3057577763070814]
# Current node: (3, 8), allowed nodes: [(4, 8), (3, 9)], probabilities: [0.5352112676056339, 0.46478873239436624]
# Current node: (4, 8), allowed nodes: [(5, 8), (4, 7), (4, 9)], probabilities: [0.3685380767092829, 0.33796553640911614, 0.29349638688160085]
# Current node: (4, 7), allowed nodes: [(5, 7), (4, 6)], probabilities: [0.4895046179680941, 0.510495382031906]
# Current node: (4, 6), allowed nodes: [(3, 6), (5, 6), (4, 5)], probabilities: [0.3421575115817339, 0.3057577763070814, 0.35208471211118464]
# Current node: (4, 5), allowed nodes: [(3, 5), (4, 4)], probabilities: [0.5229933110367893, 0.4770066889632107]
# Current node: (3, 5), allowed nodes: [(3, 4), (3, 6)], probabilities: [0.5622353937341237, 0.4377646062658764]
# Current node: (3, 4), allowed nodes: [(4, 4), (3, 3)], probabilities: [0.4104924555054706, 0.5895075444945295]
# Current node: (4, 4), allowed nodes: [(5, 4), (4, 3)], probabilities: [0.447457627118644, 0.5525423728813559]
# Current node: (5, 4), allowed nodes: [(6, 4), (5, 3)], probabilities: [0.5152542372881356, 0.48474576271186437]
# Current node: (6, 4), allowed nodes: [(7, 4), (6, 3), (6, 5)], probabilities: [0.3322734499205088, 0.3455219925808162, 0.32220455749867516]
# Current node: (7, 4), allowed nodes: [(8, 4), (7, 3), (7, 5)], probabilities: [0.3318283775234371, 0.3709380571691494, 0.2972335653074136]
# Current node: (8, 4), allowed nodes: [(9, 4), (8, 3), (8, 5)], probabilities: [0.3620987228167069, 0.33275802554366585, 0.3051432516396272]
# Current node: (8, 5), allowed nodes: [(7, 5), (9, 5), (8, 6)], probabilities: [0.31307929969104015, 0.32286302780638515, 0.36405767250257465]
# Current node: (7, 5), allowed nodes: [(6, 5), (7, 6)], probabilities: [0.5, 0.5]
# Current node: (6, 5), allowed nodes: [(6, 6)], probabilities: [1.0]
# Current node: (6, 6), allowed nodes: [(5, 6), (7, 6), (6, 7)], probabilities: [0.30715532286212915, 0.35369400814426993, 0.33915066899360097]
# Current node: (5, 6), allowed nodes: [(5, 7)], probabilities: [1.0]
# Current node: (5, 7), allowed nodes: [(6, 7), (5, 8)], probabilities: [0.4678972712680578, 0.5321027287319423]
# Current node: (5, 8), allowed nodes: [(6, 8), (5, 9)], probabilities: [0.4783634933123525, 0.5216365066876475]
# Current node: (6, 8), allowed nodes: [(7, 8), (6, 7), (6, 9)], probabilities: [0.3473022524882138, 0.30539549502357255, 0.3473022524882138]
# Current node: (7, 8), allowed nodes: [(8, 8), (7, 7), (7, 9)], probabilities: [0.31875341716785127, 0.31875341716785127, 0.36249316566429746]
# Current node: (7, 9), allowed nodes: [(6, 9), (8, 9)], probabilities: [0.5, 0.5]
# Current node: (6, 9), allowed nodes: [(5, 9)], probabilities: [1.0]
# Current node: (5, 9), allowed nodes: [(4, 9)], probabilities: [1.0]
# Current node: (4, 9), allowed nodes: [(3, 9)], probabilities: [1.0]
# Current node: (3, 9), allowed nodes: [(2, 9)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.46684978625736967, 0.5331502137426304]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.4591254454309356, 0.5408745545690644]
# Current node: (2, 0), allowed nodes: [(3, 0), (2, 1)], probabilities: [0.5085987031025447, 0.49140129689745515]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.43797606709362813, 0.5620239329063719]
# Current node: (3, 1), allowed nodes: [(2, 1), (4, 1), (3, 2)], probabilities: [0.3945424678256142, 0.2561187468239243, 0.3493387853504615]
# Current node: (2, 1), allowed nodes: [(1, 1), (2, 2)], probabilities: [0.5784468748627398, 0.42155312513726007]
# Current node: (1, 1), allowed nodes: [(0, 1), (1, 2)], probabilities: [0.5068797545709167, 0.49312024542908334]
# Current node: (0, 1), allowed nodes: [(0, 2)], probabilities: [1.0]
# Current node: (0, 2), allowed nodes: [(1, 2), (0, 3)], probabilities: [0.5654429428720573, 0.43455705712794274]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 4)], probabilities: [0.5356207140090674, 0.4643792859909325]
# Current node: (1, 3), allowed nodes: [(2, 3), (1, 2), (1, 4)], probabilities: [0.322123126291901, 0.40396737061717325, 0.2739095030909257]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 2), (2, 4)], probabilities: [0.37020441026470235, 0.3613920763196628, 0.268403513415635]
# Current node: (2, 4), allowed nodes: [(1, 4), (3, 4), (2, 5)], probabilities: [0.3635731060276594, 0.34652518048186487, 0.2899017134904758]
# Current node: (3, 4), allowed nodes: [(4, 4), (3, 3), (3, 5)], probabilities: [0.2830852305896089, 0.4065382370110917, 0.31037653239929947]
# Current node: (3, 5), allowed nodes: [(2, 5), (4, 5), (3, 6)], probabilities: [0.3462137737612964, 0.3315674665004675, 0.32221875973823627]
# Current node: (3, 6), allowed nodes: [(2, 6), (4, 6), (3, 7)], probabilities: [0.33014048531289913, 0.33971902937420184, 0.33014048531289913]
# Current node: (2, 6), allowed nodes: [(1, 6), (2, 5), (2, 7)], probabilities: [0.38029661016949157, 0.3209745762711865, 0.29872881355932207]
# Current node: (1, 6), allowed nodes: [(0, 6), (1, 5), (1, 7)], probabilities: [0.3516160626836435, 0.31733594515181196, 0.33104799216454456]
# Current node: (1, 7), allowed nodes: [(0, 7), (2, 7), (1, 8)], probabilities: [0.3642241379310345, 0.30387931034482757, 0.33189655172413796]
# Current node: (1, 8), allowed nodes: [(0, 8), (2, 8), (1, 9)], probabilities: [0.3548387096774194, 0.2903225806451613, 0.3548387096774194]
# Current node: (2, 8), allowed nodes: [(3, 8), (2, 7), (2, 9)], probabilities: [0.3206106870229008, 0.35877862595419846, 0.3206106870229008]
# Current node: (2, 7), allowed nodes: [(3, 7)], probabilities: [1.0]
# Current node: (3, 7), allowed nodes: [(4, 7), (3, 8)], probabilities: [0.5352112676056339, 0.46478873239436624]
# Current node: (3, 8), allowed nodes: [(4, 8), (3, 9)], probabilities: [0.5352112676056339, 0.46478873239436624]
# Current node: (3, 9), allowed nodes: [(2, 9), (4, 9)], probabilities: [0.5, 0.5]
# Current node: (2, 9), allowed nodes: [(1, 9)], probabilities: [1.0]
# Current node: (1, 9), allowed nodes: [(0, 9)], probabilities: [1.0]
# Current node: (0, 9), allowed nodes: [(0, 8)], probabilities: [1.0]
# Current node: (0, 8), allowed nodes: [(0, 7)], probabilities: [1.0]
# Current node: (0, 7), allowed nodes: [(0, 6)], probabilities: [1.0]
# Current node: (0, 6), allowed nodes: [(0, 5)], probabilities: [1.0]
# Current node: (0, 5), allowed nodes: [(1, 5), (0, 4)], probabilities: [0.42631578947368426, 0.5736842105263158]
# Current node: (1, 5), allowed nodes: [(2, 5), (1, 4)], probabilities: [0.44363103953147875, 0.5563689604685212]
# Current node: (1, 4), allowed nodes: [(0, 4)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.46684978625736967, 0.5331502137426304]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.4591254454309356, 0.5408745545690644]
# Current node: (1, 1), allowed nodes: [(0, 1), (2, 1), (1, 2)], probabilities: [0.3539690702171459, 0.30167053028821905, 0.34436039949463504]
# Current node: (1, 2), allowed nodes: [(0, 2), (2, 2), (1, 3)], probabilities: [0.35668607819129405, 0.2988333853802739, 0.34448053642843207]
# Current node: (1, 3), allowed nodes: [(0, 3), (2, 3), (1, 4)], probabilities: [0.34248416039460816, 0.3553514478887614, 0.3021643917166305]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 2), (2, 4)], probabilities: [0.37020441026470235, 0.3613920763196628, 0.268403513415635]
# Current node: (3, 3), allowed nodes: [(4, 3), (3, 2), (3, 4)], probabilities: [0.28083239627622353, 0.39230921436810173, 0.32685838935567474]
# Current node: (3, 2), allowed nodes: [(2, 2), (4, 2), (3, 1)], probabilities: [0.35768113146122954, 0.26130677502200467, 0.3810120935167657]
# Current node: (4, 2), allowed nodes: [(5, 2), (4, 1), (4, 3)], probabilities: [0.3359772700366994, 0.3359772700366994, 0.3280454599266011]
# Current node: (4, 1), allowed nodes: [(3, 1), (5, 1), (4, 0)], probabilities: [0.413237386808502, 0.26473347020732013, 0.3220291429841779]
# Current node: (3, 1), allowed nodes: [(2, 1), (3, 0)], probabilities: [0.49140129689745515, 0.5085987031025447]
# Current node: (3, 0), allowed nodes: [(2, 0), (4, 0)], probabilities: [0.5838814930426472, 0.41611850695735264]
# Current node: (4, 0), allowed nodes: [(5, 0)], probabilities: [1.0]
# Current node: (5, 0), allowed nodes: [(6, 0), (5, 1)], probabilities: [0.5488235544398588, 0.4511764455601413]
# Current node: (6, 0), allowed nodes: [(7, 0), (6, 1)], probabilities: [0.47422544495715224, 0.5257745550428478]
# Current node: (6, 1), allowed nodes: [(5, 1), (7, 1), (6, 2)], probabilities: [0.3042318175297662, 0.37007602926409416, 0.32569215320613976]
# Current node: (7, 1), allowed nodes: [(8, 1), (7, 0), (7, 2)], probabilities: [0.30260829861309285, 0.3079447520118715, 0.3894469493750357]
# Current node: (7, 2), allowed nodes: [(6, 2), (8, 2), (7, 3)], probabilities: [0.3188495351515322, 0.3188495351515322, 0.36230092969693567]
# Current node: (7, 3), allowed nodes: [(6, 3), (8, 3), (7, 4)], probabilities: [0.34265928834204096, 0.3278201997094011, 0.32952051194855775]
# Current node: (7, 4), allowed nodes: [(6, 4), (8, 4), (7, 5)], probabilities: [0.3208841700040359, 0.35823165999192824, 0.3208841700040359]
# Current node: (6, 4), allowed nodes: [(5, 4), (6, 3), (6, 5)], probabilities: [0.29530201342281875, 0.36465324384787473, 0.34004474272930646]
# Current node: (6, 3), allowed nodes: [(5, 3), (6, 2)], probabilities: [0.4613778705636743, 0.5386221294363257]
# Current node: (5, 3), allowed nodes: [(4, 3), (5, 2), (5, 4)], probabilities: [0.3528587800840443, 0.3613905513816376, 0.2857506685343181]
# Current node: (5, 4), allowed nodes: [(4, 4)], probabilities: [1.0]
# Current node: (4, 4), allowed nodes: [(3, 4), (4, 3), (4, 5)], probabilities: [0.37588451740730255, 0.3229549957543164, 0.301160486838381]
# Current node: (3, 4), allowed nodes: [(2, 4), (3, 5)], probabilities: [0.48708487084870844, 0.5129151291512914]
# Current node: (2, 4), allowed nodes: [(1, 4), (2, 5)], probabilities: [0.5563689604685212, 0.44363103953147875]
# Current node: (2, 5), allowed nodes: [(1, 5), (3, 5), (2, 6)], probabilities: [0.3420673769075727, 0.36020731356176217, 0.2977253095306651]
# Current node: (1, 5), allowed nodes: [(0, 5), (1, 4), (1, 6)], probabilities: [0.33958891867739055, 0.33958891867739055, 0.32082216264521896]
# Current node: (1, 6), allowed nodes: [(0, 6), (2, 6), (1, 7)], probabilities: [0.36670071501532175, 0.28804902962206336, 0.3452502553626149]
# Current node: (0, 6), allowed nodes: [(0, 5), (0, 7)], probabilities: [0.5292479108635098, 0.47075208913649025]
# Current node: (0, 5), allowed nodes: [(0, 4)], probabilities: [1.0]
# Current node: (0, 4), allowed nodes: [(1, 4), (0, 3)], probabilities: [0.4687273254970251, 0.5312726745029749]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.46684978625736967, 0.5331502137426304]
# Current node: (0, 1), allowed nodes: [(1, 1), (0, 2)], probabilities: [0.5348013916973523, 0.4651986083026476]
# Current node: (1, 1), allowed nodes: [(2, 1), (1, 0), (1, 2)], probabilities: [0.3155609480705957, 0.32422257987734504, 0.3602164720520591]
# Current node: (1, 0), allowed nodes: [(2, 0)], probabilities: [1.0]
# Current node: (2, 0), allowed nodes: [(3, 0), (2, 1)], probabilities: [0.5085987031025447, 0.49140129689745515]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.43797606709362813, 0.5620239329063719]
# Current node: (4, 0), allowed nodes: [(5, 0), (4, 1)], probabilities: [0.5318955919343532, 0.46810440806564674]
# Current node: (4, 1), allowed nodes: [(3, 1), (5, 1), (4, 2)], probabilities: [0.4298384025246204, 0.27536862723760813, 0.29479297023777135]
# Current node: (4, 2), allowed nodes: [(3, 2), (5, 2), (4, 3)], probabilities: [0.40833036131385025, 0.29936859236785396, 0.29230104631829573]
# Current node: (4, 3), allowed nodes: [(3, 3), (5, 3), (4, 4)], probabilities: [0.433421503034075, 0.2647736113272133, 0.30180488563871166]
# Current node: (3, 3), allowed nodes: [(2, 3), (3, 2), (3, 4)], probabilities: [0.3592993559371587, 0.34950512928551153, 0.2911955147773297]
# Current node: (3, 2), allowed nodes: [(2, 2), (3, 1)], probabilities: [0.48420794907369624, 0.5157920509263038]
# Current node: (2, 2), allowed nodes: [(1, 2), (2, 1), (2, 3)], probabilities: [0.3740512710692329, 0.3276806667202042, 0.298268062210563]
# Current node: (2, 3), allowed nodes: [(1, 3), (2, 4)], probabilities: [0.6081692837002354, 0.3918307162997646]
# Current node: (1, 3), allowed nodes: [(0, 3), (1, 2), (1, 4)], probabilities: [0.3141229959507065, 0.4087348907139256, 0.27714211333536787]
# Current node: (0, 3), allowed nodes: [(0, 2), (0, 4)], probabilities: [0.544269552385637, 0.45573044761436304]
# Current node: (0, 2), allowed nodes: [(1, 2)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.46684978625736967, 0.5331502137426304]
# Current node: (0, 1), allowed nodes: [(1, 1), (0, 2)], probabilities: [0.5348013916973523, 0.4651986083026476]
# Current node: (1, 1), allowed nodes: [(2, 1), (1, 0), (1, 2)], probabilities: [0.3155609480705957, 0.32422257987734504, 0.3602164720520591]
# Current node: (1, 2), allowed nodes: [(0, 2), (2, 2), (1, 3)], probabilities: [0.35668607819129405, 0.2988333853802739, 0.34448053642843207]
# Current node: (1, 3), allowed nodes: [(0, 3), (2, 3), (1, 4)], probabilities: [0.34248416039460816, 0.3553514478887614, 0.3021643917166305]
# Current node: (0, 3), allowed nodes: [(0, 2), (0, 4)], probabilities: [0.544269552385637, 0.45573044761436304]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.46684978625736967, 0.5331502137426304]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.4591254454309356, 0.5408745545690644]
# Current node: (2, 0), allowed nodes: [(3, 0), (2, 1)], probabilities: [0.5085987031025447, 0.49140129689745515]
# Current node: (2, 1), allowed nodes: [(1, 1), (3, 1), (2, 2)], probabilities: [0.39919032021667533, 0.30989285695181684, 0.2909168228315078]
# Current node: (2, 2), allowed nodes: [(1, 2), (3, 2), (2, 3)], probabilities: [0.3886421263912259, 0.30145507979993236, 0.3099027938088418]
# Current node: (2, 3), allowed nodes: [(1, 3), (3, 3), (2, 4)], probabilities: [0.3948009202505499, 0.35083712572839176, 0.2543619540210583]
# Current node: (2, 4), allowed nodes: [(1, 4), (3, 4), (2, 5)], probabilities: [0.3635731060276594, 0.34652518048186487, 0.2899017134904758]
# Current node: (3, 4), allowed nodes: [(4, 4), (3, 3), (3, 5)], probabilities: [0.2830852305896089, 0.4065382370110917, 0.31037653239929947]
# Current node: (3, 5), allowed nodes: [(2, 5), (4, 5), (3, 6)], probabilities: [0.3462137737612964, 0.3315674665004675, 0.32221875973823627]
# Current node: (2, 5), allowed nodes: [(1, 5), (2, 6)], probabilities: [0.5346534653465347, 0.4653465346534653]
# Current node: (1, 5), allowed nodes: [(0, 5), (1, 4), (1, 6)], probabilities: [0.33958891867739055, 0.33958891867739055, 0.32082216264521896]
# Current node: (0, 5), allowed nodes: [(0, 4), (0, 6)], probabilities: [0.5484276729559748, 0.45157232704402517]
# Current node: (0, 4), allowed nodes: [(1, 4), (0, 3)], probabilities: [0.4687273254970251, 0.5312726745029749]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 2)], probabilities: [0.4912962614674106, 0.5087037385325894]
# Current node: (1, 3), allowed nodes: [(1, 2), (1, 4)], probabilities: [0.5959303028106043, 0.4040696971893956]
# Current node: (1, 2), allowed nodes: [(0, 2), (1, 1)], probabilities: [0.4651986083026476, 0.5348013916973523]
# Current node: (0, 2), allowed nodes: [(0, 1)], probabilities: [1.0]
# Current node: (0, 1), allowed nodes: [(1, 1)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.46684978625736967, 0.5331502137426304]
# ...
# Current node: (4, 0), allowed nodes: [(3, 0), (5, 0)], probabilities: [0.8814266772629024, 0.11857332273709757]
# Current node: (3, 0), allowed nodes: [(2, 0)], probabilities: [1.0]
# Current node: (2, 0), allowed nodes: [(1, 0)], probabilities: [1.0]
# Current node: (1, 0), allowed nodes: [(1, 1)], probabilities: [1.0]
# Current node: (1, 1), allowed nodes: [(1, 2)], probabilities: [1.0]
# Current node: (1, 2), allowed nodes: [(1, 3)], probabilities: [1.0]
# Current node: (1, 3), allowed nodes: [(1, 4)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.4771659927267037, 0.5228340072732963]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.49437641863793874, 0.5056235813620613]
# Current node: (1, 1), allowed nodes: [(0, 1), (2, 1), (1, 2)], probabilities: [0.347586571154313, 0.2953816208337173, 0.3570318080119697]
# Current node: (0, 1), allowed nodes: [(0, 2)], probabilities: [1.0]
# Current node: (0, 2), allowed nodes: [(1, 2), (0, 3)], probabilities: [0.6394064057460054, 0.3605935942539945]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 4)], probabilities: [0.7263952219909993, 0.2736047780090007]
# Current node: (1, 3), allowed nodes: [(2, 3), (1, 2), (1, 4)], probabilities: [0.1953113679359653, 0.601380318563067, 0.20330831350096779]
# Current node: (1, 4), allowed nodes: [(0, 4), (2, 4), (1, 5)], probabilities: [0.38157799714531687, 0.1712531889026443, 0.4471688139520388]
# Current node: (1, 5), allowed nodes: [(0, 5), (2, 5), (1, 6)], probabilities: [0.5441514217104862, 0.08465478033478722, 0.37119379795472657]
# Current node: (1, 6), allowed nodes: [(0, 6), (2, 6), (1, 7)], probabilities: [0.5315651181894276, 0.11563835356172647, 0.35279652824884594]
# Current node: (0, 6), allowed nodes: [(0, 5), (0, 7)], probabilities: [0.5114682060357442, 0.48853179396425583]
# Current node: (0, 7), allowed nodes: [(1, 7), (0, 8)], probabilities: [0.5876691222034873, 0.41233087779651256]
# Current node: (0, 8), allowed nodes: [(1, 8), (0, 9)], probabilities: [0.8410378511063348, 0.1589621488936652]
# Current node: (0, 9), allowed nodes: [(1, 9)], probabilities: [1.0]
# Current node: (1, 9), allowed nodes: [(2, 9), (1, 8)], probabilities: [0.28634494342355965, 0.7136550565764402]
# Current node: (2, 9), allowed nodes: [(3, 9), (2, 8)], probabilities: [0.3449782222114491, 0.655021777788551]
# Current node: (3, 9), allowed nodes: [(4, 9), (3, 8)], probabilities: [0.36995228389290263, 0.6300477161070973]
# Current node: (4, 9), allowed nodes: [(5, 9), (4, 8)], probabilities: [0.4413341944447178, 0.5586658055552822]
# Current node: (4, 8), allowed nodes: [(3, 8), (5, 8), (4, 7)], probabilities: [0.44743277196786907, 0.30782999824601887, 0.24473722978611204]
# Current node: (4, 7), allowed nodes: [(3, 7), (5, 7), (4, 6)], probabilities: [0.5261742190369063, 0.3514900096992866, 0.12233577126380714]
# Current node: (3, 7), allowed nodes: [(2, 7), (3, 6), (3, 8)], probabilities: [0.40909942621507506, 0.13880202559224167, 0.4520985481926832]
# Current node: (3, 8), allowed nodes: [(2, 8)], probabilities: [1.0]
# Current node: (2, 8), allowed nodes: [(1, 8), (2, 7)], probabilities: [0.5159508767411535, 0.4840491232588465]
# Current node: (2, 7), allowed nodes: [(1, 7), (2, 6)], probabilities: [0.7531388928280349, 0.24686110717196497]
# Current node: (2, 6), allowed nodes: [(3, 6), (2, 5)], probabilities: [0.5049749050382066, 0.49502509496179337]
# Current node: (2, 5), allowed nodes: [(3, 5), (2, 4)], probabilities: [0.21124643131267776, 0.7887535686873223]
# Current node: (2, 4), allowed nodes: [(3, 4), (2, 3)], probabilities: [0.16243149120273467, 0.8375685087972653]
# Current node: (2, 3), allowed nodes: [(3, 3), (2, 2)], probabilities: [0.3878615516806729, 0.6121384483193271]
# Current node: (2, 2), allowed nodes: [(1, 2), (3, 2), (2, 1)], probabilities: [0.4309020680166715, 0.21260154030301642, 0.35649639168031205]
# Current node: (2, 1), allowed nodes: [(3, 1), (2, 0)], probabilities: [0.3630124502533808, 0.6369875497466191]
# Current node: (2, 0), allowed nodes: [(3, 0)], probabilities: [1.0]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.42451955292879945, 0.5754804470712005]
# Current node: (4, 0), allowed nodes: [(5, 0), (4, 1)], probabilities: [0.10120723216885316, 0.8987927678311468]
# Current node: (4, 1), allowed nodes: [(3, 1), (5, 1), (4, 2)], probabilities: [0.503328219966985, 0.1160815528336615, 0.3805902271993534]
# Current node: (4, 2), allowed nodes: [(3, 2), (5, 2), (4, 3)], probabilities: [0.5012308661739056, 0.14383583129507918, 0.3549333025310153]
# Current node: (3, 2), allowed nodes: [(3, 1), (3, 3)], probabilities: [0.5353285670905222, 0.4646714329094778]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.4771659927267037, 0.5228340072732963]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.49437641863793874, 0.5056235813620613]
# Current node: (1, 1), allowed nodes: [(0, 1), (2, 1), (1, 2)], probabilities: [0.347586571154313, 0.2953816208337173, 0.3570318080119697]
# Current node: (1, 2), allowed nodes: [(0, 2), (2, 2), (1, 3)], probabilities: [0.44544254600058664, 0.2882487215696234, 0.26630873242979003]
# Current node: (2, 2), allowed nodes: [(3, 2), (2, 1), (2, 3)], probabilities: [0.29984304016387775, 0.5027854536544046, 0.19737150618171753]
# Current node: (3, 2), allowed nodes: [(4, 2), (3, 1), (3, 3)], probabilities: [0.2881484115098184, 0.381074490847561, 0.3307770976426206]
# Current node: (3, 3), allowed nodes: [(2, 3), (4, 3), (3, 4)], probabilities: [0.44058690339443324, 0.4739691156403326, 0.08544398096523405]
# Current node: (2, 3), allowed nodes: [(1, 3), (2, 4)], probabilities: [0.8553980078986, 0.14460199210140007]
# Current node: (1, 3), allowed nodes: [(0, 3), (1, 4)], probabilities: [0.6252084766114878, 0.37479152338851207]
# Current node: (1, 4), allowed nodes: [(0, 4), (2, 4), (1, 5)], probabilities: [0.38157799714531687, 0.1712531889026443, 0.4471688139520388]
# Current node: (0, 4), allowed nodes: [(0, 3), (0, 5)], probabilities: [0.6546408251027094, 0.34535917489729057]
# Current node: (0, 3), allowed nodes: [(0, 2)], probabilities: [1.0]
# Current node: (0, 2), allowed nodes: [(0, 1)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.4771659927267037, 0.5228340072732963]
# Current node: (0, 1), allowed nodes: [(1, 1), (0, 2)], probabilities: [0.4587946186102787, 0.5412053813897213]
# Current node: (1, 1), allowed nodes: [(2, 1), (1, 0), (1, 2)], probabilities: [0.3046304026964741, 0.3271586600652755, 0.3682109372382504]
# Current node: (2, 1), allowed nodes: [(3, 1), (2, 0), (2, 2)], probabilities: [0.24244441453637816, 0.42542362791548044, 0.33213195754814134]
# Current node: (2, 2), allowed nodes: [(1, 2), (3, 2), (2, 3)], probabilities: [0.5500069200994269, 0.2713663430037939, 0.17862673689677921]
# Current node: (1, 2), allowed nodes: [(0, 2), (1, 3)], probabilities: [0.6258401768984806, 0.3741598231015194]
# Current node: (0, 2), allowed nodes: [(0, 3)], probabilities: [1.0]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 4)], probabilities: [0.7263952219909993, 0.2736047780090007]
# Current node: (1, 3), allowed nodes: [(2, 3), (1, 4)], probabilities: [0.48996920380828246, 0.5100307961917175]
# Current node: (1, 4), allowed nodes: [(0, 4), (2, 4), (1, 5)], probabilities: [0.38157799714531687, 0.1712531889026443, 0.4471688139520388]
# Current node: (1, 5), allowed nodes: [(0, 5), (2, 5), (1, 6)], probabilities: [0.5441514217104862, 0.08465478033478722, 0.37119379795472657]
# Current node: (0, 5), allowed nodes: [(0, 4), (0, 6)], probabilities: [0.434327772747351, 0.565672227252649]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.4771659927267037, 0.5228340072732963]
# Current node: (1, 0), allowed nodes: [(2, 0), (1, 1)], probabilities: [0.49437641863793874, 0.5056235813620613]
# Current node: (2, 0), allowed nodes: [(3, 0), (2, 1)], probabilities: [0.30908166035802803, 0.6909183396419719]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.42451955292879945, 0.5754804470712005]
# Current node: (4, 0), allowed nodes: [(5, 0), (4, 1)], probabilities: [0.10120723216885316, 0.8987927678311468]
# Current node: (4, 1), allowed nodes: [(3, 1), (5, 1), (4, 2)], probabilities: [0.503328219966985, 0.1160815528336615, 0.3805902271993534]
# Current node: (5, 1), allowed nodes: [(6, 1), (5, 0), (5, 2)], probabilities: [0.32585571886187936, 0.17538658647905683, 0.49875769465906367]
# Current node: (5, 2), allowed nodes: [(4, 2), (6, 2), (5, 3)], probabilities: [0.5705464115386534, 0.1620929469562699, 0.26736064150507666]
# Current node: (4, 2), allowed nodes: [(3, 2), (4, 3)], probabilities: [0.58543779860829, 0.4145622013917099]
# Current node: (3, 2), allowed nodes: [(2, 2), (3, 1), (3, 3)], probabilities: [0.42308674464692664, 0.30883814632368933, 0.2680751090293841]
# Current node: (3, 3), allowed nodes: [(2, 3), (4, 3), (3, 4)], probabilities: [0.44058690339443324, 0.4739691156403326, 0.08544398096523405]
# Current node: (4, 3), allowed nodes: [(5, 3), (4, 4)], probabilities: [0.6963147924057839, 0.3036852075942161]
# Current node: (5, 3), allowed nodes: [(6, 3), (5, 4)], probabilities: [0.6178823398921838, 0.38211766010781617]
# Current node: (6, 3), allowed nodes: [(7, 3), (6, 2), (6, 4)], probabilities: [0.4291148981537203, 0.2895183961737658, 0.2813667056725139]
# Current node: (7, 3), allowed nodes: [(8, 3), (7, 2), (7, 4)], probabilities: [0.444330276642667, 0.2857569817556426, 0.2699127416016903]
# Current node: (7, 2), allowed nodes: [(6, 2), (8, 2), (7, 1)], probabilities: [0.23889868516832016, 0.37746899056586164, 0.38363232426581817]
# Current node: (8, 2), allowed nodes: [(9, 2), (8, 1), (8, 3)], probabilities: [0.2640139885815753, 0.3673100274714961, 0.36867598394692863]
# Current node: (8, 1), allowed nodes: [(7, 1), (9, 1), (8, 0)], probabilities: [0.3356673969083469, 0.3321664007870224, 0.33216620230463073]
# Current node: (7, 1), allowed nodes: [(6, 1), (7, 0)], probabilities: [0.3602986913052214, 0.6397013086947785]
# Current node: (6, 1), allowed nodes: [(6, 0), (6, 2)], probabilities: [0.4745340725312398, 0.5254659274687602]
# Current node: (6, 0), allowed nodes: [(5, 0), (7, 0)], probabilities: [0.23262817892260543, 0.7673718210773947]
# Current node: (7, 0), allowed nodes: [(8, 0)], probabilities: [1.0]
# Current node: (8, 0), allowed nodes: [(9, 0)], probabilities: [1.0]
# Current node: (9, 0), allowed nodes: [(9, 1)], probabilities: [1.0]
# Current node: (9, 1), allowed nodes: [(9, 2)], probabilities: [1.0]
# Current node: (9, 2), allowed nodes: [(9, 3)], probabilities: [1.0]
# Current node: (9, 3), allowed nodes: [(8, 3), (9, 4)], probabilities: [0.8432745201938486, 0.15672547980615129]
# Current node: (8, 3), allowed nodes: [(8, 4)], probabilities: [1.0]
# Current node: (8, 4), allowed nodes: [(7, 4), (9, 4), (8, 5)], probabilities: [0.7657249684412709, 0.2342750067502085, 2.480852059188246e-08]
# Current node: (7, 4), allowed nodes: [(6, 4), (7, 5)], probabilities: [0.827914559891079, 0.17208544010892107]
# Current node: (7, 5), allowed nodes: [(6, 5), (8, 5), (7, 6)], probabilities: [1.7472822365593087e-10, 1.545112274053052e-07, 0.9999998453140444]
# Current node: (7, 6), allowed nodes: [(6, 6), (8, 6), (7, 7)], probabilities: [0.218064107814741, 0.47018034152823607, 0.31175555065702293]
# Current node: (7, 7), allowed nodes: [(6, 7), (8, 7), (7, 8)], probabilities: [0.4709063051960112, 0.32435447045615357, 0.2047392243478353]
# Current node: (6, 7), allowed nodes: [(5, 7), (6, 6), (6, 8)], probabilities: [0.4224054688109233, 0.11958780329630406, 0.4580067278927727]
# Current node: (6, 8), allowed nodes: [(5, 8), (7, 8), (6, 9)], probabilities: [0.4600580174608806, 0.14864969040647152, 0.39129229213264805]
# Current node: (5, 8), allowed nodes: [(4, 8), (5, 7), (5, 9)], probabilities: [0.4042771622983612, 0.2763524126977262, 0.31937042500391255]
# Current node: (5, 7), allowed nodes: [(4, 7), (5, 6)], probabilities: [0.7512324435136862, 0.24876755648631377]
# Current node: (5, 6), allowed nodes: [(4, 6), (6, 6)], probabilities: [0.5514430756436541, 0.44855692435634603]
# Current node: (6, 6), allowed nodes: [(6, 5)], probabilities: [1.0]
# Current node: (6, 5), allowed nodes: [(6, 4)], probabilities: [1.0]
# Current node: (6, 4), allowed nodes: [(5, 4)], probabilities: [1.0]
# Current node: (5, 4), allowed nodes: [(4, 4)], probabilities: [1.0]
# Current node: (4, 4), allowed nodes: [(3, 4), (4, 5)], probabilities: [0.6919194615431506, 0.30808053845684935]
# Current node: (4, 5), allowed nodes: [(3, 5), (4, 6)], probabilities: [0.48460078254163635, 0.5153992174583637]
# Current node: (3, 5), allowed nodes: [(2, 5), (3, 4), (3, 6)], probabilities: [0.2957811162998857, 0.40249268307758335, 0.30172620062253097]
# Current node: (3, 4), allowed nodes: [(2, 4)], probabilities: [1.0]
# Current node: (2, 4), allowed nodes: [(1, 4), (2, 3), (2, 5)], probabilities: [0.4767408211675895, 0.45798865934084915, 0.06527051949156142]
# Current node: (1, 4), allowed nodes: [(0, 4), (1, 3), (1, 5)], probabilities: [0.20717657432683947, 0.5500345234999099, 0.24278890217325055]
# Current node: (1, 5), allowed nodes: [(0, 5), (2, 5), (1, 6)], probabilities: [0.5441514217104862, 0.08465478033478722, 0.37119379795472657]
# Current node: (0, 5), allowed nodes: [(0, 4), (0, 6)], probabilities: [0.434327772747351, 0.565672227252649]
# Current node: (0, 4), allowed nodes: [(0, 3)], probabilities: [1.0]
# Current node: (0, 3), allowed nodes: [(1, 3), (0, 2)], probabilities: [0.3741598231015194, 0.6258401768984806]
# Current node: (1, 3), allowed nodes: [(2, 3), (1, 2)], probabilities: [0.24515301370124506, 0.7548469862987549]
# Current node: (1, 2), allowed nodes: [(0, 2), (2, 2), (1, 1)], probabilities: [0.40082830758220206, 0.25937856243604845, 0.33979312998174954]
# Current node: (0, 2), allowed nodes: [(0, 1)], probabilities: [1.0]
# Current node: (0, 1), allowed nodes: [(1, 1)], probabilities: [1.0]
# Current node: (1, 1), allowed nodes: [(2, 1)], probabilities: [1.0]
# Current node: (2, 1), allowed nodes: [(3, 1), (2, 2)], probabilities: [0.42195333173344424, 0.5780466682665557]
# Current node: (2, 2), allowed nodes: [(2, 3)], probabilities: [1.0]
# Current node: (0, 0), allowed nodes: [(1, 0), (0, 1)], probabilities: [0.4771659927267037, 0.5228340072732963]
# Current node: (0, 1), allowed nodes: [(1, 1), (0, 2)], probabilities: [0.4587946186102787, 0.5412053813897213]
# Current node: (1, 1), allowed nodes: [(2, 1), (1, 0), (1, 2)], probabilities: [0.3046304026964741, 0.3271586600652755, 0.3682109372382504]
# Current node: (1, 0), allowed nodes: [(2, 0)], probabilities: [1.0]
# Current node: (2, 0), allowed nodes: [(3, 0), (2, 1)], probabilities: [0.30908166035802803, 0.6909183396419719]
# Current node: (3, 0), allowed nodes: [(4, 0), (3, 1)], probabilities: [0.42451955292879945, 0.5754804470712005]
# Current node: (3, 1), allowed nodes: [(2, 1), (4, 1), (3, 2)], probabilities: [0.46930744784304007, 0.25081458251798117, 0.2798779696389787]
# Current node: (3, 2), allowed nodes: [(2, 2), (4, 2), (3, 3)], probabilities: [0.4575449315256153, 0.2525466538136268, 0.28990841466075784]
# Current node: (2, 2), allowed nodes: [(1, 2), (2, 1), (2, 3)], probabilities: [0.4646629443941863, 0.38442763523165063, 0.15090942037416297]
# Current node: (2, 3), allowed nodes: [(1, 3), (3, 3), (2, 4)], probabilities: [0.5391228742896528, 0.369740320515732, 0.09113680519461502]
# Current node: (1, 3), allowed nodes: [(0, 3), (1, 2), (1, 4)], probabilities: [0.2965008517702282, 0.525756826943219, 0.17774232128655268]
# Current node: (1, 4), allowed nodes: [(0, 4), (2, 4), (1, 5)], probabilities: [0.38157799714531687, 0.1712531889026443, 0.4471688139520388]
# Current node: (0, 4), allowed nodes: [(0, 3), (0, 5)], probabilities: [0.6546408251027094, 0.34535917489729057]
# Current node: (0, 3), allowed nodes: [(0, 2)], probabilities: [1.0]
# Current node: (0, 2), allowed nodes: [(1, 2)], probabilities: [1.0]
# 最优路径: [(1, 0), (1, 1), (1, 2), (0, 2), (0, 1)]
